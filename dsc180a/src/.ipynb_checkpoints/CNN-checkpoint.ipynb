# %%
import os
import argparse
import time
from datetime import datetime, date
import random

import numpy as np
from scipy.sparse import load_npz
from scipy.stats import pearsonr
from sklearn.metrics import roc_auc_score, precision_recall_curve, auc
import pandas as pd

import torch
import torch_geometric
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F

from model_classes_ import GCN_classification, GCN_regression
from custom_funcs import experiment_n

# %%
torch.cuda.empty_cache()

# %%
print(torch.cuda.is_available())  # Should print `True`
print(torch.cuda.device_count())  # Should print the number of GPUs available
print(torch.cuda.current_device())  # Should print the current GPU ID (e.g., `0`)
print(torch.cuda.get_device_name(0))  # Should print the GPU name
# Out:
# True
# 1
# 0
# NVIDIA RTX A5000

# %% [markdown]
# # Data Preparation

# %%
# Hyperparameters

chip_res = 10000
hic_res = 10000
num_hm = 6
num_feat = int((hic_res/chip_res)*num_hm)
regression_flag = 0
max_epoch = 50
learning_rate = 0.001
num_lin_layers = 2
lin_hidden_size = 100
num_graph_conv_layers = 2
graph_conv_embed_size = 256
num_runs = 10
graph_conv_layer_sizes = [num_feat] + \
        [int(max(graph_conv_embed_size, lin_hidden_size)) \
              for i in np.arange(1, num_graph_conv_layers, 1)] + [lin_hidden_size]

lin_hidden_sizes_r = [graph_conv_layer_sizes[-1]] + \
        [int(max(lin_hidden_size, 1)) \
              for i in np.arange(1, num_lin_layers, 1)] + [1]
lin_hidden_sizes_c = [graph_conv_layer_sizes[-1]] + \
        [int(max(lin_hidden_size, 2)) \
              for i in np.arange(1, num_lin_layers, 1)] + [2]

# %%
# Stores AUROC and PCC across all models for each cell line
E116 = {'name': 'E116', 'AUROC': None, 'PCC': None}
E122 = {'name': 'E122', 'AUROC': None, 'PCC': None}
E123 = {'name': 'E123', 'AUROC': None, 'PCC': None}

# %%
def experimentCNN(model, cell_line, regression_flag, optimizer, criterion, num_epochs=10):
    if regression_flag == 1:
        task = 'Regression'
    else:
        task = 'Classification'
    
    print(f"Task: {task}")
    # Create all paths
    base_path = os.getcwd()
    hic_sparse_mat_file = os.path.join(base_path, 'data', cell_line['name'], 'hic_sparse.npz')
    np_hmods_norm_all_file = os.path.join(base_path, 'data', cell_line['name'], \
        'np_hmods_norm_chip_' + str(chip_res) + 'bp.npy')
    np_nodes_lab_genes_file = os.path.join(base_path, 'data',  cell_line['name'], \
        'np_nodes_lab_genes_reg' + str(regression_flag) + '.npy')
    
    allNodes_hms = np.load(np_hmods_norm_all_file)
    hms = allNodes_hms[:, 1:] # only includes features, not node ids
    X = torch.tensor(hms).float().reshape(-1, num_feat) # shape: [279606, 6]
    allNodes = allNodes_hms[:, 0].astype(int) # shape: [279606,1]
    
    geneNodes_labs = np.load(np_nodes_lab_genes_file)
    geneNodes = geneNodes_labs[:, -2].astype(int) # shape: [16699,1]
    allLabs = -1*np.ones(np.shape(allNodes))
    
    targetNode_mask = torch.tensor(geneNodes).long()

    # Generate y labels
    geneLabs = geneNodes_labs[:, -1].astype(int)
    allLabs[geneNodes] = geneLabs
    Y = torch.tensor(allLabs).long() # shape: [279606,1]

    # Shuffle indices
    pred_idx_shuff = torch.randperm(targetNode_mask.shape[0])
    
    fin_train = np.floor(0.7*pred_idx_shuff.shape[0]).astype(int)
    fin_valid = np.floor(0.85*pred_idx_shuff.shape[0]).astype(int)
    train_idx = pred_idx_shuff[:fin_train]
    val_idx = pred_idx_shuff[fin_train:fin_valid]
    test_idx = pred_idx_shuff[fin_valid:]

    # Generate train, validation, and test sets
    train_data = X[targetNode_mask][train_idx]
    val_data = X[targetNode_mask][val_idx]
    test_data = X[targetNode_mask][test_idx]
    

    if not regression_flag:
        train_labels = torch.tensor(geneNodes_labs[train_idx][:,1]).long()
        val_labels = torch.tensor(geneNodes_labs[val_idx][:,1]).long()
        test_labels = torch.tensor(geneNodes_labs[test_idx][:,1]).long()
    else:
        train_labels = torch.tensor(geneNodes_labs[train_idx][:,1]).float()
        val_labels = torch.tensor(geneNodes_labs[val_idx][:,1]).float()
        test_labels = torch.tensor(geneNodes_labs[test_idx][:,1]).float()
        

    # Reformat data
    train_data = train_data.unsqueeze(1)
    val_data = val_data.unsqueeze(1)
    test_data = test_data.unsqueeze(1)

    # Create data loaders
    BATCH_SIZE = 32
    
    print("Create data loaders")
    train_dataset = TensorDataset(train_data, train_labels)
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    
    val_dataset = TensorDataset(val_data, val_labels)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True)
    
    test_dataset = TensorDataset(test_data, test_labels)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True)
    print("Data loaders created")
    print(f"Train loader shape: {len(train_loader)}")
    print(f"Val loader shape: {len(val_loader)}")
    print(f"Test loader shape: {len(test_loader)}")

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    
    print(f"Device: {device}")

    # Train data
    print("Begin training + evaluation...\n\n")
    metric_scores = []
    for epoch in range(num_epochs):
        start = time.time()
        epoch_loss = 0
        for batch_inputs, batch_labels in train_loader:
            batch_inputs, batch_labels = batch_inputs.to(device), batch_labels.to(device)
            optimizer.zero_grad()
            
            output = model(batch_inputs)
            if regression_flag:
                batch_labels = batch_labels.view(-1, 1)
                
            loss = criterion(output, batch_labels)
            
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item()
            
        end = time.time()
        avg_loss = epoch_loss / len(train_loader)
        print(f"Training time: {end-start} seconds")
        print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {avg_loss:.4f}\n")

        model.eval()
        test_outputs = []
        test_targets = []
        start = time.time()
        with torch.no_grad():
            for batch_inputs, batch_labels in test_loader:
                batch_inputs, batch_labels = batch_inputs.to(device), batch_labels.to(device)
                output = model(batch_inputs).squeeze()
                test_outputs.append(output)
                test_targets.append(batch_labels)
        
        test_outputs = torch.cat(test_outputs).cpu().numpy()
        test_targets = torch.cat(test_targets).cpu().numpy()
        
        end = time.time()
        print(f"Testing time: {end-start} seconds")
        if regression_flag == 0:
            test_outputs = test_outputs[:, 1]
            auroc = roc_auc_score(test_targets, test_outputs)
            print(f"Epoch {epoch + 1}, AUROC Score: {auroc:.4f}")
            metric_scores.append(auroc)
        else:
            # Calculate PCC for regression
            pcc, _ = pearsonr(test_targets, test_outputs)
            print(f"Epoch {epoch + 1}, PCC Score: {pcc:.4f}")
            metric_scores.append(pcc)
    
    metric_scores = np.array(metric_scores)
    if regression_flag == 0:
        cell_line['AUROC'] = (np.mean(metric_scores), np.std(metric_scores))
    else:
        cell_line['PCC'] = (np.mean(metric_scores), np.std(metric_scores))

# %% [markdown]
# # Model

# %%
class CNN(nn.Module):
    def __init__(self, regression_flag=0):
        super(CNN, self).__init__()

        INPUT_LENGTH = 6
        NUM_CLASSES = 2 if not regression_flag else 1
        
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=16, kernel_size=3, padding=1)
        
        self.fc1 = nn.Linear(16 * INPUT_LENGTH, 32)
        self.fc2 = nn.Linear(32, NUM_CLASSES)
        
        self.relu = nn.ReLU()
        
    def forward(self, x):
            x = self.relu(self.conv1(x))
            x = x.view(x.size(0), -1)         
            x = self.relu(self.fc1(x))
            x = self.fc2(x)  
            return x

# %% [markdown]
# # Model Training And Evaluation

# %%
for regression_flag in [0,1]:
    for cell_line in [E116,E122,E123]:
        print(f"Cell line: {cell_line['name']}")
        model = CNN(regression_flag=regression_flag)
        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
        criterion = nn.MSELoss() if regression_flag else nn.CrossEntropyLoss()
        experimentCNN(model, cell_line, regression_flag, optimizer, criterion)
# Out:
# Cell line: E116
# Task: Classification
# Create data loaders
# Data loaders created
# Train loader shape: 366
# Val loader shape: 79
# Test loader shape: 79
# Device: cuda
# Begin training + evaluation...
#
#
# Training time: 2.1782033443450928 seconds
# Epoch 1/10, Loss: 0.4676
#
# Testing time: 0.028039932250976562 seconds
# Epoch 1, AUROC Score: 0.9034
# Training time: 0.4017362594604492 seconds
# Epoch 2/10, Loss: 0.3881
#
# Testing time: 0.03195357322692871 seconds
# Epoch 2, AUROC Score: 0.9050
# Training time: 0.35201382637023926 seconds
# Epoch 3/10, Loss: 0.3813
#
# Testing time: 0.027225017547607422 seconds
# Epoch 3, AUROC Score: 0.9066
# Training time: 0.5927956104278564 seconds
# Epoch 4/10, Loss: 0.3794
#
# Testing time: 0.04784870147705078 seconds
# Epoch 4, AUROC Score: 0.9069
# Training time: 0.8290596008300781 seconds
# Epoch 5/10, Loss: 0.3780
#
# Testing time: 0.06592273712158203 seconds
# Epoch 5, AUROC Score: 0.9076
# Training time: 0.8488574028015137 seconds
# Epoch 6/10, Loss: 0.3774
#
# Testing time: 0.05107259750366211 seconds
# Epoch 6, AUROC Score: 0.9078
# Training time: 0.6342132091522217 seconds
# Epoch 7/10, Loss: 0.3767
#
# Testing time: 0.047258853912353516 seconds
# Epoch 7, AUROC Score: 0.9074
# Training time: 0.36130499839782715 seconds
# Epoch 8/10, Loss: 0.3773
#
# Testing time: 0.026910066604614258 seconds
# Epoch 8, AUROC Score: 0.9083
# Training time: 0.36414480209350586 seconds
# Epoch 9/10, Loss: 0.3754
#
# Testing time: 0.026932239532470703 seconds
# Epoch 9, AUROC Score: 0.9083
# Training time: 0.3634469509124756 seconds
# Epoch 10/10, Loss: 0.3745
#
# Testing time: 0.027005910873413086 seconds
# Epoch 10, AUROC Score: 0.9087
# Cell line: E122
# Task: Classification
# Create data loaders
# Data loaders created
# Train loader shape: 365
# Val loader shape: 79
# Test loader shape: 79
# Device: cuda
# Begin training + evaluation...
#
#
# Training time: 0.6549129486083984 seconds
# Epoch 1/10, Loss: 0.5254
#
# Testing time: 0.03133106231689453 seconds
# Epoch 1, AUROC Score: 0.8702
# Training time: 0.37737536430358887 seconds
# Epoch 2/10, Loss: 0.4300
#
# Testing time: 0.027820587158203125 seconds
# Epoch 2, AUROC Score: 0.8739
# Training time: 0.3654348850250244 seconds
# Epoch 3/10, Loss: 0.4228
#
# Testing time: 0.027186870574951172 seconds
# Epoch 3, AUROC Score: 0.8757
# Training time: 0.36342787742614746 seconds
# Epoch 4/10, Loss: 0.4185
#
# Testing time: 0.02710580825805664 seconds
# Epoch 4, AUROC Score: 0.8776
# Training time: 0.36292362213134766 seconds
# Epoch 5/10, Loss: 0.4159
#
# Testing time: 0.027092456817626953 seconds
# Epoch 5, AUROC Score: 0.8782
# Training time: 0.3631448745727539 seconds
# Epoch 6/10, Loss: 0.4134
#
# Testing time: 0.027052879333496094 seconds
# Epoch 6, AUROC Score: 0.8794
# Training time: 0.36316561698913574 seconds
# Epoch 7/10, Loss: 0.4113
#
# Testing time: 0.027089834213256836 seconds
# Epoch 7, AUROC Score: 0.8809
# Training time: 0.3625638484954834 seconds
# Epoch 8/10, Loss: 0.4110
#
# Testing time: 0.02688121795654297 seconds
# Epoch 8, AUROC Score: 0.8816
# Training time: 0.35940027236938477 seconds
# Epoch 9/10, Loss: 0.4097
#
# Testing time: 0.02681565284729004 seconds
# Epoch 9, AUROC Score: 0.8823
# Training time: 0.35932183265686035 seconds
# Epoch 10/10, Loss: 0.4083
#
# Testing time: 0.026786327362060547 seconds
# Epoch 10, AUROC Score: 0.8830
# Cell line: E123
# Task: Classification
# Create data loaders
# Data loaders created
# Train loader shape: 366
# Val loader shape: 79
# Test loader shape: 79
# Device: cuda
# Begin training + evaluation...
#
#
# Training time: 0.4524109363555908 seconds
# Epoch 1/10, Loss: 0.4835
#
# Testing time: 0.028881072998046875 seconds
# Epoch 1, AUROC Score: 0.9085
# Training time: 0.3482398986816406 seconds
# Epoch 2/10, Loss: 0.3725
#
# Testing time: 0.026806354522705078 seconds
# Epoch 2, AUROC Score: 0.9121
# Training time: 0.351642370223999 seconds
# Epoch 3/10, Loss: 0.3647
#
# Testing time: 0.027510881423950195 seconds
# Epoch 3, AUROC Score: 0.9132
# Training time: 0.6438562870025635 seconds
# Epoch 4/10, Loss: 0.3592
#
# Testing time: 0.06757688522338867 seconds
# Epoch 4, AUROC Score: 0.9136
# Training time: 0.8557772636413574 seconds
# Epoch 5/10, Loss: 0.3580
#
# Testing time: 0.05268287658691406 seconds
# Epoch 5, AUROC Score: 0.9143
# Training time: 0.7688910961151123 seconds
# Epoch 6/10, Loss: 0.3570
#
# Testing time: 0.06643247604370117 seconds
# Epoch 6, AUROC Score: 0.9144
# Training time: 0.8335113525390625 seconds
# Epoch 7/10, Loss: 0.3553
#
# Testing time: 0.05398273468017578 seconds
# Epoch 7, AUROC Score: 0.9150
# Training time: 0.6384539604187012 seconds
# Epoch 8/10, Loss: 0.3531
#
# Testing time: 0.047768354415893555 seconds
# Epoch 8, AUROC Score: 0.9152
# Training time: 0.36502623558044434 seconds
# Epoch 9/10, Loss: 0.3518
#
# Testing time: 0.027669191360473633 seconds
# Epoch 9, AUROC Score: 0.9157
# Training time: 0.36830925941467285 seconds
# Epoch 10/10, Loss: 0.3518
#
# Testing time: 0.026968002319335938 seconds
# Epoch 10, AUROC Score: 0.9160
# Cell line: E116
# Task: Regression
# Create data loaders
# Data loaders created
# Train loader shape: 366
# Val loader shape: 79
# Test loader shape: 79
# Device: cuda
# Begin training + evaluation...
#
#
# Training time: 0.841641902923584 seconds
# Epoch 1/10, Loss: 0.2629
#
# Testing time: 0.04929184913635254 seconds
# Epoch 1, PCC Score: 0.7490
# Training time: 0.6453988552093506 seconds
# Epoch 2/10, Loss: 0.1803
#
# Testing time: 0.04530906677246094 seconds
# Epoch 2, PCC Score: 0.7701
# Training time: 0.3707916736602783 seconds
# Epoch 3/10, Loss: 0.1751
#
# Testing time: 0.028475046157836914 seconds
# Epoch 3, PCC Score: 0.7747
# Training time: 0.37131834030151367 seconds
# Epoch 4/10, Loss: 0.1729
#
# Testing time: 0.027770042419433594 seconds
# Epoch 4, PCC Score: 0.7767
# Training time: 0.3717532157897949 seconds
# Epoch 5/10, Loss: 0.1724
#
# Testing time: 0.028168439865112305 seconds
# Epoch 5, PCC Score: 0.7775
# Training time: 0.6510448455810547 seconds
# Epoch 6/10, Loss: 0.1707
#
# Testing time: 0.049956560134887695 seconds
# Epoch 6, PCC Score: 0.7771
# Training time: 0.6347339153289795 seconds
# Epoch 7/10, Loss: 0.1718
#
# Testing time: 0.04863691329956055 seconds
# Epoch 7, PCC Score: 0.7782
# Training time: 0.6400160789489746 seconds
# Epoch 8/10, Loss: 0.1713
#
# Testing time: 0.03961825370788574 seconds
# Epoch 8, PCC Score: 0.7779
# Training time: 0.36644959449768066 seconds
# Epoch 9/10, Loss: 0.1706
#
# Testing time: 0.027990102767944336 seconds
# Epoch 9, PCC Score: 0.7777
# Training time: 0.36653900146484375 seconds
# Epoch 10/10, Loss: 0.1701
#
# Testing time: 0.02789449691772461 seconds
# Epoch 10, PCC Score: 0.7790
# Cell line: E122
# Task: Regression
# Create data loaders
# Data loaders created
# Train loader shape: 365
# Val loader shape: 79
# Test loader shape: 79
# Device: cuda
# Begin training + evaluation...
#
#
# Training time: 0.7823851108551025 seconds
# Epoch 1/10, Loss: 0.3240
#
# Testing time: 0.04882645606994629 seconds
# Epoch 1, PCC Score: 0.6798
# Training time: 0.6225104331970215 seconds
# Epoch 2/10, Loss: 0.2149
#
# Testing time: 0.03986167907714844 seconds
# Epoch 2, PCC Score: 0.7142
# Training time: 0.372894287109375 seconds
# Epoch 3/10, Loss: 0.2035
#
# Testing time: 0.02875041961669922 seconds
# Epoch 3, PCC Score: 0.7224
# Training time: 0.5543844699859619 seconds
# Epoch 4/10, Loss: 0.1997
#
# Testing time: 0.04793524742126465 seconds
# Epoch 4, PCC Score: 0.7267
# Training time: 0.739738941192627 seconds
# Epoch 5/10, Loss: 0.1982
#
# Testing time: 0.06627607345581055 seconds
# Epoch 5, PCC Score: 0.7296
# Training time: 0.8399124145507812 seconds
# Epoch 6/10, Loss: 0.1967
#
# Testing time: 0.05252480506896973 seconds
# Epoch 6, PCC Score: 0.7316
# Training time: 0.6874234676361084 seconds
# Epoch 7/10, Loss: 0.1952
#
# Testing time: 0.06553888320922852 seconds
# Epoch 7, PCC Score: 0.7339
# Training time: 0.3871183395385742 seconds
# Epoch 8/10, Loss: 0.1944
#
# Testing time: 0.03563404083251953 seconds
# Epoch 8, PCC Score: 0.7351
# Training time: 0.6531059741973877 seconds
# Epoch 9/10, Loss: 0.1928
#
# Testing time: 0.05863833427429199 seconds
# Epoch 9, PCC Score: 0.7361
# Training time: 0.6432852745056152 seconds
# Epoch 10/10, Loss: 0.1918
#
# Testing time: 0.04942893981933594 seconds
# Epoch 10, PCC Score: 0.7371
# Cell line: E123
# Task: Regression
# Create data loaders
# Data loaders created
# Train loader shape: 366
# Val loader shape: 79
# Test loader shape: 79
# Device: cuda
# Begin training + evaluation...
#
#
# Training time: 0.576387882232666 seconds
# Epoch 1/10, Loss: 0.2533
#
# Testing time: 0.02854466438293457 seconds
# Epoch 1, PCC Score: 0.7645
# Training time: 0.35634493827819824 seconds
# Epoch 2/10, Loss: 0.1684
#
# Testing time: 0.028058767318725586 seconds
# Epoch 2, PCC Score: 0.7799
# Training time: 0.35303688049316406 seconds
# Epoch 3/10, Loss: 0.1629
#
# Testing time: 0.027930736541748047 seconds
# Epoch 3, PCC Score: 0.7834
# Training time: 0.3532085418701172 seconds
# Epoch 4/10, Loss: 0.1600
#
# Testing time: 0.028116703033447266 seconds
# Epoch 4, PCC Score: 0.7842
# Training time: 0.35697150230407715 seconds
# Epoch 5/10, Loss: 0.1599
#
# Testing time: 0.02792525291442871 seconds
# Epoch 5, PCC Score: 0.7847
# Training time: 0.36893653869628906 seconds
# Epoch 6/10, Loss: 0.1590
#
# Testing time: 0.028057098388671875 seconds
# Epoch 6, PCC Score: 0.7854
# Training time: 0.37201738357543945 seconds
# Epoch 7/10, Loss: 0.1584
#
# Testing time: 0.028412818908691406 seconds
# Epoch 7, PCC Score: 0.7856
# Training time: 0.36721229553222656 seconds
# Epoch 8/10, Loss: 0.1591
#
# Testing time: 0.027869224548339844 seconds
# Epoch 8, PCC Score: 0.7861
# Training time: 0.36702442169189453 seconds
# Epoch 9/10, Loss: 0.1574
#
# Testing time: 0.02837514877319336 seconds
# Epoch 9, PCC Score: 0.7864
# Training time: 0.36743640899658203 seconds
# Epoch 10/10, Loss: 0.1569
#
# Testing time: 0.027962684631347656 seconds
# Epoch 10, PCC Score: 0.7864

# %%
print(f'E116:{E116}')
print(f'E122:{E122}')
print(f'E123:{E123}')
# Out:
# E116:{'name': 'E116', 'AUROC': (0.9069986248800769, 0.0015646891630204229), 'PCC': (0.7738009239108016, 0.008594149149206467)}
# E122:{'name': 'E122', 'AUROC': (0.8782818178563117, 0.0038688479196454257), 'PCC': (0.724645884551897, 0.01638523255753388)}
# E123:{'name': 'E123', 'AUROC': (0.9137923576986078, 0.002092590506195945), 'PCC': (0.7826535817580295, 0.006321086803171246)}

# %%
with open('results/CNN.csv', 'w') as f:
    f.write('cell_line,auroc_mu,auroc_std,pcc_mu,pcc_std\n')
    f.write(f"E116,{E116['AUROC'][0]},{E116['AUROC'][1]},{E116['PCC'][0]},{E116['PCC'][1]}\n")
    f.write(f"E122,{E122['AUROC'][0]},{E122['AUROC'][1]},{E122['PCC'][0]},{E122['PCC'][1]}\n")
    f.write(f"E123,{E123['AUROC'][0]},{E123['AUROC'][1]},{E123['PCC'][0]},{E123['PCC'][1]}\n")

f.close()
